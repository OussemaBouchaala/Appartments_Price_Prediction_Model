# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("immobilier_vendre.csv")

# %%
import unicodedata
import re

def normalize_city(city):
    if not isinstance(city, str):
        return city
    
    # minuscules
    city = city.lower()
    
    # supprimer accents
    city = unicodedata.normalize("NFKD", city)
    city = city.encode("ascii", "ignore").decode("utf-8")
    
    # supprimer les déterminants au début
    city = re.sub(r"^(la |el |al )\s+", "", city)
    
    # supprimer tirets et espaces inutiles
    city = city.replace("-", " ").strip()
    
    return city

# %%
df["city"] = df["city"].apply(normalize_city)

# %%
import matplotlib.pyplot as plt
# Bar plot du nombre d'annonces par ville
plt.figure(figsize=(14, 6))
df['city'].value_counts().plot(kind='bar', color='steelblue', alpha=0.8)
plt.xlabel('Ville')
plt.ylabel('Fréquence')
plt.title('Distribution des appartements par ville')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
df['superficie'].value_counts().plot(kind='bar', color='steelblue', alpha=0.8)
plt.xlabel('Superficie (m²)')
plt.ylabel('Fréquence')
plt.title('Distribution des appartements par superficie')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
df['price'].value_counts().plot(kind='bar', color='steelblue', alpha=0.8)
plt.xlabel('price')
plt.ylabel('Frequency')
plt.title('Distribution of apartments by price')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
df['chambres'].value_counts().plot(kind='bar', color='steelblue', alpha=0.8)
plt.xlabel('Nombre de chambres')
plt.ylabel('Fréquence')
plt.title('Distribution des appartements par nombre de chambres')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
df['bains'].value_counts().plot(kind='bar', color='steelblue')
plt.xlabel('Nombre de bains')
plt.ylabel('Fréquence')
plt.title('Distribution des appartements par nombre de bains')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print(df["price"].describe())
# Out:
# count    1.560000e+03
# mean     1.000935e+07
# std      2.877414e+08
# min      1.200000e+00
# 25%      1.800000e+05
# 50%      2.900000e+05
# 75%      4.600000e+05
# max      1.111111e+10
# Name: price, dtype: float64
